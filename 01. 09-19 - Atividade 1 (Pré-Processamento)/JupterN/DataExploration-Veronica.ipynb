# %% [markdown]
# # Tipos de Dados

# %%
from IPython.display import Image
Image("TiposDados.png", width=300, height=300)

# %%
import pandas as pd

data = pd.read_csv("./Dados-PreProc-F.csv")
data.head()#printa os 5 primeiros registros
# Out:
#    ID Sintoma Altura-1  Altura-2  Peso  Temperatura  Idade  Sexo
# 0   1   Febre    Baixa         0  45.3         36.5     55     0
# 1   2   Tosse    Media         1  70.7         36.5     45     1
# 2   3   Tosse     Alta         2  98.2         37.9     37     1
# 3   4   Tosse     Alta         2  99.1         36.5     32     1
# 4   5   Febre     Alta         2  92.5         36.5     35     1

# %%
print(data)
# Out:
#    ID Sintoma Altura-1  Altura-2  Peso  Temperatura  Idade  Sexo
# 0   1   Febre    Baixa         0  45.3         36.5     55     0
# 1   2   Tosse    Media         1  70.7         36.5     45     1
# 2   3   Tosse     Alta         2  98.2         37.9     37     1
# 3   4   Tosse     Alta         2  99.1         36.5     32     1
# 4   5   Febre     Alta         2  92.5         36.5     35     1
# 5   6  Corisa     Alta         2  91.7         36.5     62     0
# 6   7  Corisa    Media         1  72.4         38.9     65     0
# 7   8  Corisa    Baixa         0  50.2         36.5     37     0
# 8   9  Corisa    Baixa         0  57.3         38.8     33     0
# 9  10  Corisa    Baixa         0  59.9         36.5     31     0

# %%
#tupla: linhas, colunas
data.shape
# Out:
# (10, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           10 non-null     int64
#  1   Sintoma      10 non-null     object
#  2   Altura-1     10 non-null     object
#  3   Altura-2     10 non-null     int64
#  4   Peso         10 non-null     float64
#  5   Temperatura  10 non-null     float64
#  6   Idade        10 non-null     int64
#  7   Sexo         10 non-null     int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 768.0+ bytes

# %%
#Observação
#Ordinal, em geral:
   #Treated as interval data - Altura-2 [razão permitiria *;/] - corrida: 1 lugar, não é o dobro
    #de 2 lugar - tem o tempo da corrida, por exemplo
   #Treated as categorical (ignore the order) - codificação (encoding) (mais em codificação (aula posterior))

# %%
#atributos qualitativos
#freqência
#idem Altura-1
data['Sintoma'].value_counts()
# Out:
# Corisa    5
# Tosse     3
# Febre     2
# Name: Sintoma, dtype: int64

# %%
#moda
#idem Altura-1
data['Sintoma'].mode()
# Out:
# 0    Corisa
# Name: Sintoma, dtype: object

# %%
#atributos quantitativos
#Quantil
data['Peso'].quantile([.1, .5])
# Out:
# 0.1    49.71
# 0.5    71.55
# Name: Peso, dtype: float64

# %%
data.sort_values(by=['Peso'])
# Out:
#    ID Sintoma Altura-1  Altura-2  Peso  Temperatura  Idade  Sexo
# 0   1   Febre    Baixa         0  45.3         36.5     55     0
# 7   8  Corisa    Baixa         0  50.2         36.5     37     0
# 8   9  Corisa    Baixa         0  57.3         38.8     33     0
# 9  10  Corisa    Baixa         0  59.9         36.5     31     0
# 1   2   Tosse    Media         1  70.7         36.5     45     1
# 6   7  Corisa    Media         1  72.4         38.9     65     0
# 5   6  Corisa     Alta         2  91.7         36.5     62     0
# 4   5   Febre     Alta         2  92.5         36.5     35     1
# 2   3   Tosse     Alta         2  98.2         37.9     37     1
# 3   4   Tosse     Alta         2  99.1         36.5     32     1

# %%
data['Peso'].mean()
# Out:
# 73.72999999999999

# %%
#posição central dos valores
#média entre os Ids 1 e 6
data['Peso'].median()
# Out:
# 71.55000000000001

# %%
#range, aplitude
data['Peso'].max() - data['Peso'].min()
# Out:
# 53.8

# %%
#variância
data['Peso'].var()
# Out:
# 416.86011111111117

# %%
#desvio-padrão
data['Peso'].std()
# Out:
# 20.417152375174926

# %%
data.std()
# Out:
# <ipython-input-25-a47ac8255c06>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.std()
# ID              3.027650
# Altura-2        0.942809
# Peso           20.417152
# Temperatura     1.015929
# Idade          12.882374
# Sexo            0.516398
# dtype: float64

# %%
import matplotlib

data['Peso'].hist(bins=4)
# Out:
# <Axes: >

# %%
import seaborn as sns

sns.histplot(data['Peso'], bins=4, color="red", stat="density",kde=True,element="step")
# Out:
# <Axes: xlabel='Peso', ylabel='Density'>

# %%
sns.boxplot(x='Peso', data=data, showmeans=True)
# Out:
# <Axes: xlabel='Peso'>

# %%
sns.boxplot(x='Sintoma', y='Peso', data=data, showmeans=True)
# Out:
# <Axes: xlabel='Sintoma', ylabel='Peso'>
